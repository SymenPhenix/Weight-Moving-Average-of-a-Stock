# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as web
from pandas_datareader.data import YahooOptions as opt
from datetime import datetime as date
import mplfinance as mpl
from fbprophet import Prophet
from pandas_datareader import get_data_stooq as yahoo

# %%
start = date(2019,9,5)

# %%
sq = yahoo('sq',start)

# %%
sq.tail()
# Out:
#              Open   High     Low  Close    Volume
# Date
# 2019-09-11  60.85  60.85  58.910  59.20  11561437
# 2019-09-10  60.72  62.10  59.450  60.55   9394002
# 2019-09-09  62.55  62.73  59.070  61.47  11684380
# 2019-09-06  63.50  63.85  61.890  62.00   4744128
# 2019-09-05  61.88  63.47  61.669  63.02   8162318

# %%
sq['MA5'] = sq['Close'].ewm(5).mean()
sq['MA21'] = sq['Close'].ewm(21).mean()
sq['MA100'] = sq['Close'].ewm(100).mean()

# %%
sq.loc['2021-07-01':][['Close','MA5','MA21','MA100']].plot(figsize=(10,10));
